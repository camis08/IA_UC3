# %% [markdown]
# <a href="https://colab.research.google.com/github/camis08/IA_UC3/blob/main/UC3_funcoes_polinomiais_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UC3 — Funções Polinomiais aplicadas à Inteligência Artificial
# ## Aula: Modelando fenômenos com funções polinomiais
#
# **Curso:** Técnico em Inteligência Artificial
# **Unidade Curricular:** UC3 — Aplicar funções de lógica matemática em Inteligência Artificial
# **Situação de Aprendizagem 3:** Funções polinomiais e modelagem de fenômenos
# **Carga horária sugerida:** 3h
# **Indicador:** Compreende e aplica funções matemáticas polinomiais
#
# ---
#
# ## Objetivos da aula
# Ao final desta aula, você deverá ser capaz de:
#
# - compreender o que é uma função polinomial;
# - identificar o comportamento de funções do 2º grau;
# - relacionar tabela, expressão algébrica e gráfico;
# - aplicar funções polinomiais em problemas práticos;
# - perceber como esse conteúdo aparece em contextos de IA e análise de dados.

# %% [markdown]
# ## 1. Revisão rápida: o que é uma função?
#
# Uma função é uma regra que relaciona uma **entrada** `x` a uma **saída** `f(x)`.
#
# Exemplo:
#
# \[
# f(x) = 2x + 3
# \]
#
# Quando a expressão possui potências de `x`, como `x²`, `x³` etc., temos uma **função polinomial**.
#
# ---
#
# ## 2. O que é uma função polinomial?
#
# Uma função polinomial é uma função escrita como soma de termos do tipo:
#
# \[
# a_nx^n + a_{n-1}x^{n-1} + \dots + a_1x + a_0
# \]
#
# Exemplos:
#
# - \(f(x) = 3x + 1\) → polinomial do 1º grau
# - \(f(x) = x^2 + 2x + 1\) → polinomial do 2º grau
# - \(f(x) = x^3 - 4x\) → polinomial do 3º grau
#
# Nesta aula, vamos focar principalmente na função polinomial do **2º grau**, também chamada de **função quadrática**:
#
# \[
# f(x) = ax^2 + bx + c
# \]
#
# onde:
#
# - `a` controla a concavidade;
# - `b` influencia a inclinação e a posição do vértice;
# - `c` é o valor onde a curva corta o eixo `y`.

# %% [markdown]
# ## 3. Exemplo do cotidiano
#
# Imagine a trajetória de uma bola lançada para cima.
# Ela sobe, atinge uma altura máxima e depois desce.
#
# Esse comportamento não é linear.
# Ele pode ser modelado por uma função quadrática.
#
# Exemplo:
#
# \[
# h(t) = -5t^2 + 20t + 1
# \]
#
# onde:
#
# - `t` = tempo
# - `h(t)` = altura da bola
#
# Perceba:
#
# - o termo `-5t²` faz a curva "abrir para baixo";
# - existe um ponto máximo;
# - o gráfico não é uma reta, e sim uma **parábola**.

# %%
# Exemplo 1: calculando a altura da bola em diferentes instantes
#h é de hight
def h(t):
    return -5*t**2 + 20*t + 1

tempos = [0, 1, 2, 3, 4]
[(t, h(t)) for t in tempos]
# Out:
# [(0, 1), (1, 16), (2, 21), (3, 16), (4, 1)]

# %%
"""
h(t) = -5t² + 20t + 1
h(0) = -5* 0² + 20*0 + 1
h(0) = 1

h(1) = -5* 1² + 20*1 + 1
h(1) = -5 + 20 + 1
h(1) = 16

h(2) = -5 * 2² + 20 * 2 + 1
h(2) = -20 + 40 + 1
h(2) = 21
"""
for t in tempos:
    print(f'( {t} ,  {h(t)})')
# Out:
# ( 0 ,  1)
# ( 1 ,  16)
# ( 2 ,  21)
# ( 3 ,  16)
# ( 4 ,  1)

# %% [markdown]
# ### Exercício 1
#
# Complete a tabela para a função:
#
# \[
# f(x) = x^2 + 2x + 3
# \]
#
# | x | f(x) |
# |---|------|
# | 0 | ? |
# | 1 | ? |
# | 2 | ? |
# | 3 | ? |
#
# Tente responder antes de executar a célula abaixo.

# %%
#f(x) = x**2 + 2*x + 3

def f(x):
    return x**2 + 2*x + 3

valores = [0, 1, 2, 3]
[(x, f(x)) for x in valores]
        #ou
for x in valores:
    print(f'( {x} ,  {f(x)})')
# Out:
# ( 0 ,  3)
# ( 1 ,  6)
# ( 2 ,  11)
# ( 3 ,  18)

# %%
"""
# Resposta Prof

def f(x):
    return x**2 + 2*x + 3

valores = [0, 1, 2, 3]
[(x, f(x)) for x in valores]
"""
# Out:
# '\n# Resposta Prof\n\ndef f(x):\n    return x**2 + 2*x + 3\n\nvalores = [0, 1, 2, 3]\n[(x, f(x)) for x in valores]\n'

# %% [markdown]
# ## 4. Representação gráfica
#
# A função quadrática gera, em geral, uma **parábola**.
#
# Vamos visualizar o gráfico do exemplo da bola.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
linspace cria números com base na quantidade de pontos desejados (incluindo o valor final),
enquanto o arange cria números com base no tamanho do passo (step) entre eles

"""
t = np.linspace(0, 4.5, 200)
altura = -5*t**2 + 20*t + 1

plt.figure(figsize=(8, 5))
#plt.plot(t, altura)
#ou
plt.stem(t,altura)

plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

plt.title("Trajetória da bola")
plt.xlabel("Tempo")
plt.ylabel("Altura")
plt.grid()
plt.show()

# %% [markdown]
# ### O que observar no gráfico?
#
# 1. A parábola está voltada para cima ou para baixo?
# 2. Existe um ponto de altura máxima?
# 3. Em que parte do gráfico a bola sobe?
# 4. Em que parte do gráfico a bola desce?
#
# ---
#
# ## 5. Entendendo o papel dos coeficientes
#
# Na função:
#
# \[
# f(x) = ax^2 + bx + c
# \]
#
# ### Papel de `a`
# - Se `a > 0`, a parábola abre para cima.
# - Se `a < 0`, a parábola abre para baixo.
#
# ### Papel de `c`
# - É o valor da função quando `x = 0`.
# - Indica o ponto em que a curva cruza o eixo `y`.
#
# ### Papel de `b`
# - Ajuda a determinar a posição do vértice e o comportamento da curva.

# %%
# Comparando diferentes valores de a

x = np.linspace(-5, 5, 300)

y1 = x**2
y2 = 2*x**2
y3 = -x**2

plt.figure(figsize=(8, 5))
plt.plot(x, y1, label="f(x) = x²")
plt.plot(x, y2, label="f(x) = 2x²")
plt.plot(x, y3, label="f(x) = -x²")
plt.title("Influência do coeficiente a")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Exercício 2
#
# Observe as funções abaixo e responda:
#
# 1. Qual delas abre para cima?
# 2. Qual delas abre para baixo?
# 3. Qual tem crescimento mais "rápido"?
#
# - \(f(x) = x^2\)
# - \(g(x) = 3x^2\)
# - \(h(x) = -2x^2\)

# %%
#Qual delas abre para cima?
"""A primeira e a segunda"""
#Qual delas abre para baixo?
"""A última """
#Qual tem crescimento mais "rápido"?
"""A segunda """
# Out:
# 'A segunda '

# %% [markdown]
# ## 6. Construindo a função a partir de uma situação
#
# ### Exemplo 2
#
# Uma empresa está analisando o desempenho de um pequeno experimento de treinamento.
#
# Ao longo do tempo, o desempenho do modelo melhora no início, atinge um ponto ideal e depois piora por excesso de ajuste em um parâmetro.
#
# Um modelo simplificado para representar esse comportamento é:
#
# \[
# p(x) = -x^2 + 6x + 2
# \]
#
# onde:
#
# - `x` = valor de ajuste do parâmetro
# - `p(x)` = desempenho do modelo
#
# A ideia aqui não é ensinar o treinamento real de IA ainda, mas mostrar que **nem todo comportamento é uma reta**.

# %%
# Exemplo 2: avaliando desempenho em diferentes valores do parâmetro

def desempenho(x):
    return -x**2 + 6*x + 2

parametros = [0, 1, 2, 3, 4, 5, 6]
[(x, desempenho(x)) for x in parametros]
# Out:
# [(0, 2), (1, 7), (2, 10), (3, 11), (4, 10), (5, 7), (6, 2)]

# %%
# Gráfico do desempenho

x = np.linspace(0, 6, 200)
y = -x**2 + 6*x + 2

plt.figure(figsize=(8, 5))
plt.plot(x, y)
plt.title("Desempenho do modelo em função de um parâmetro")
plt.xlabel("Parâmetro")
plt.ylabel("Desempenho")
plt.grid()
plt.show()

# %% [markdown]
# ## 7. Onde isso aparece em IA?
#
# Aqui está a conexão importante desta aula com Inteligência Artificial:
#
# ### 1. Relações não lineares nos dados
# Nem todo fenômeno do mundo real cresce em linha reta.
# Muitas relações são curvas.
#
# Exemplos:
# - evolução de erro e acerto em experimentos;
# - impacto de um parâmetro no desempenho do modelo;
# - trajetórias, movimentos e sinais;
# - ajuste de curvas em análise de dados.
#
# ### 2. Engenharia de atributos
# No futuro, vocês verão que às vezes usamos variáveis como:
#
# - `x`
# - `x²`
# - `x³`
#
# para ajudar um modelo de IA a capturar padrões mais complexos.
#
# ### 3. Regressão polinomial
# Mais adiante, vocês verão uma técnica em que o modelo aprende padrões curvos em vez de apenas uma reta.
#
# **Resumo para guardar:**
#
# > Função polinomial ajuda a modelar comportamentos curvos.
# > Em IA, isso é útil quando os dados não seguem uma relação linear simples.

# %% [markdown]
# ## 8. Aplicação prática com Python
#
# Agora vamos criar e visualizar outra função polinomial.

# %%
# Exemplo 3: custo de erro em função de uma escolha inadequada de parâmetro

def custo(x):
    return x**2 - 4*x + 5

for x in [0, 1, 2, 3, 4]:
    print(f"x = {x} -> custo = {custo(x)}")
# Out:
# x = 0 -> custo = 5
# x = 1 -> custo = 2
# x = 2 -> custo = 1
# x = 3 -> custo = 2
# x = 4 -> custo = 5

# %%
# Gráfico do custo

x = np.linspace(-1, 5, 300)
y = x**2 - 4*x + 5

plt.figure(figsize=(8, 5))
plt.plot(x, y)
plt.title("Função polinomial: custo em função de x")
plt.xlabel("x")
plt.ylabel("custo(x)")
plt.grid()
plt.show()

# %% [markdown]
# ### Exercício 3
#
# Considere a função:
#
# \[
# g(x) = x^2 - 4x + 5
# \]
#
# Responda:
#
# 1. Quanto vale `g(0)`?
# 2. Quanto vale `g(2)`?
# 3. A parábola abre para cima ou para baixo?
# 4. O gráfico parece ter um ponto mínimo ou máximo?

# %%
def desempenho(x):
    return x**2 - 4*x + 5

parametros = [0,2]
[(x, desempenho(x)) for x in parametros]

#for x in [0, 1, 2, 3, 4]:
    #print(f"x = {x} -> custo = {custo(x)}")
# Out:
# [(0, 5), (2, 1)]

# %%
x = np.linspace(0, 3, 100)
y = x**2 - 4*x + 5

plt.figure(figsize=(8, 5))
plt.plot(x, y)
plt.title("Função polinomial: custo em função de x")
plt.xlabel("x")
plt.ylabel("custo(x)")
plt.grid()
plt.show()

# %% [markdown]
# ## 9. Atividade prática
#
# Crie uma função polinomial para representar uma das situações abaixo:
#
# 1. a altura de um objeto lançado;
# 2. o desempenho de um experimento que melhora e depois piora;
# 3. um custo que diminui até certo ponto e depois volta a subir.
#
# Depois:
#
# - escreva a função;
# - calcule alguns valores;
# - faça o gráfico no Python;
# - explique o que o gráfico representa.

# %%
# Crie aqui sua própria função polinomial

# def minha_funcao(x):
#     return ...

# teste = [0, 1, 2, 3, 4]
# [(x, minha_funcao(x)) for x in teste]

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# x = np.linspace(-5, 5, 300)
# y = minha_funcao(x)

# plt.figure(figsize=(8, 5))
# plt.plot(x, y)
# plt.grid()
# plt.show()

# %% [markdown]
# #A cereja do bolo

# %% [markdown]
# Vamos verificar ainda a diferença de graus

# %%
import numpy as np
import matplotlib.pyplot as plt

# dados (você pode mudar esses valores)
x = np.array([1, 2, 3, 4, 5])
y = np.array([3, 7, 13, 21, 31])  # comportamento polinomial

# ajuste polinomial grau 2
coeficientes = np.polyfit(x, y, 1)

# cria função a partir dos coeficientes
funcao = np.poly1d(coeficientes)

print("Função encontrada pela IA:")
print(funcao)
# Out:
# Função encontrada pela IA:
#
# 7 x - 6

# %%
# gerar pontos para o gráfico
x_linha = np.linspace(1, 5, 100)
y_linha = funcao(x_linha)

plt.scatter(x, y, label="Dados reais")
plt.plot(x_linha, y_linha, color='red', label="Função encontrada")
plt.legend()
plt.grid()
plt.show()

# %%
"""
não é bom a função chegar perto dos pontos
OVERFIT
100% IA não é bom, ah não ser que seja com um grande número de dados
"""
# Out:
# '\nnão é bom a função chegar perto dos pontos\nOVERFIT\n100% IA não é bom, ah não ser que seja com um grande número de dados\n'

# %%
funcao(8)
# Out:
# np.float64(50.0)

# %% [markdown]
# ## 10. Exercícios de fixação
#
# ### Exercício 4
# Considere a função:
#
# \[
# f(x) = 2x^2 + 3x + 1
# \]
#
# Calcule:
#
# - `f(0)`
# - `f(1)`
# - `f(2)`
#
# ---
#
# ### Exercício 5
# Diga se cada função abre para cima ou para baixo:
#
# - \(f(x) = 4x^2 - 1\)
# - \(g(x) = -x^2 + 7\)
# - \(h(x) = -3x^2 + 2x\)
#
# ---
#
# ### Exercício 6
# Explique com suas palavras a diferença entre:
#
# - uma função linear;
# - uma função polinomial do 2º grau.
#
# ---
#
# ### Exercício 7
# Observe a função:
#
# \[
# f(x) = -2x^2 + 8x + 1
# \]
#
# Sem calcular exatamente o vértice, responda:
#
# - o gráfico tem ponto máximo ou mínimo?
# - por quê?

# %% [markdown]
# ## 11. Desafios opcionais — para quem quiser ir além
#
# ### Desafio 1
# Crie uma função polinomial que tenha:
#
# - concavidade para cima;
# - valor inicial igual a 4;
# - crescimento rápido.
#
# Explique por que a sua escolha atende às condições.
#
# ---
#
# ### Desafio 2
# Monte um problema do cotidiano ou da tecnologia que possa ser representado por uma função polinomial.
#
# Depois:
#
# - escreva a função;
# - explique o significado de cada termo;
# - gere o gráfico.
#
# ---
#
# ### Desafio 3
# Pesquise e explique, com suas palavras:
#
# **Por que alguns problemas de IA não podem ser representados apenas por uma reta?**
#
# Dê pelo menos um exemplo.
#
# ---
#
# ### Desafio 4
# Use Python para comparar no mesmo gráfico:
#
# \[
# f(x) = x^2
# \]
#
# e
#
# \[
# g(x) = 2x^2 + 3x + 1
# \]
#
# Depois escreva:
#
# - qual cresce mais rápido;
# - qual parece mais deslocada no plano;
# - qual informação os coeficientes acrescentam.

# %%
# Espaço para os desafios opcionais

# Use este espaço para resolver os desafios.

# %% [markdown]
# ## 12. Fechamento da aula
#
# ### Ideias principais
#
# - função polinomial representa relações que podem ser curvas;
# - a função do 2º grau gera uma parábola;
# - os coeficientes mudam o formato e a posição do gráfico;
# - esse conteúdo aparece em modelagem matemática, análise de dados e IA.
#
# ### Conexão com o futuro
#
# Mais adiante, vocês verão com mais profundidade temas como:
#
# - regressão;
# - ajuste de curvas;
# - modelos que aprendem padrões mais complexos;
# - uso de variáveis transformadas como `x²` em problemas de IA.
#
# Hoje, o foco foi construir a base matemática para entender isso melhor no futuro.
