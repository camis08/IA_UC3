# %% [markdown]
# <a href="https://colab.research.google.com/github/camis08/IA_UC3/blob/main/UC3_Funcao_Linear_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UC3 — Funções Lineares aplicadas à Inteligência Artificial
# ## Aula: Modelando problemas com funções lineares
#
# **Curso:** Técnico em Inteligência Artificial
# **Unidade Curricular:** UC3 — Aplicar funções de lógica matemática em Inteligência Artificial
# **Duração sugerida:** 3h
# **Indicador:** Compreende e aplica funções matemáticas lineares
#
# ---
#
# ### Objetivos da aula
# Ao final desta aula, você deverá ser capaz de:
#
# - compreender o que é uma função linear;
# - identificar os elementos da função `f(x) = ax + b`;
# - interpretar o significado de `a` e `b` em situações reais;
# - construir gráficos de funções lineares;
# - relacionar função linear com a ideia de **previsão** em IA;
# - entender, em nível introdutório, como isso aparece em **regressão linear**.
#
# ---
#
# ### Onde isso aparece na IA?
# A função linear aparece em vários contextos de IA e Ciência de Dados:
#
# - em **modelos preditivos simples**, como regressão linear;
# - como base do cálculo interno de modelos mais complexos;
# - na ideia de **peso** e **viés** (`weight` e `bias`);
# - na relação entre **variáveis de entrada** e **saída prevista**.
#
# > Em termos simples: uma IA aprende uma fórmula que relaciona entradas e saídas.
# > A função linear é uma das formas mais simples dessa relação.

# %% [markdown]
# ## 1. Revisão rápida: o que é uma função?
#
# Uma função é uma regra que associa cada valor de entrada a um único valor de saída.
#
# Exemplo:
#
# - entrada: quantidade de quilômetros rodados
# - saída: preço da corrida
#
# Se o preço depende da distância, podemos representar isso por uma função.
#
# ---
#
# ## 2. Função linear
#
# A forma geral da função linear que vamos usar nesta aula é:
#
# \[
# f(x) = ax + b
# \]
#
# Onde:
#
# - `x` = valor de entrada;
# - `f(x)` = valor de saída;
# - `a` = taxa de variação / inclinação da reta;
# - `b` = valor inicial / ponto onde a reta corta o eixo y.
#
# ### Interpretação
# - Se `a > 0`, a função cresce.
# - Se `a < 0`, a função decresce.
# - Se `b = 0`, a reta passa pela origem.

# %%
"""

Função Linear :
 **[f(x) = ax + b]**
* x = valor entrada
* f(x) = valor saída
* a = taxa variação / inclinação reta
* b = valor inicial / ponto reta corta eixo y

https://pt.symbolab.com/graphing-calculator  --> Symbolab
https://www.geogebra.org/calculator  --> GeoGebra

f: y = x
b = 0 /  a = 1

"""
# Out:
# '\n\nFunção Linear :\n **[f(x) = ax + b]**\n* x = valor entrada\n* f(x) = valor saída\n* a = taxa variação / inclinação reta\n* b = valor inicial / ponto reta corta eixo y\n\nhttps://pt.symbolab.com/graphing-calculator  --> Symbolab\nhttps://www.geogebra.org/calculator  --> GeoGebra\n\nf: y = x\nb = 0 /  a = 1\n\n'

# %% [markdown]
# ## 3. Exemplo do cotidiano
#
# Uma empresa de armazenamento em nuvem cobra:
#
# - taxa fixa de **R\$ 20**
# - mais **R\$ 5 por GB** armazenado
#
# Podemos modelar isso por:
#
# \[
# f(x) = 5x + 20
# \]
#
# Onde:
#
# - `x` = quantidade de GB armazenados
# - `f(x)` = custo total
#
# ### Interpretação
# - `a = 5`: a cada 1 GB, o custo aumenta R\$ 5
# - `b = 20`: mesmo sem usar nenhum GB, existe uma taxa fixa de R\$ 20

# %%
# Exemplo 1: calculando valores da função f(x) = 5x + 20

def f(x):
    return 5*x + 20

for x in [0, 1, 2, 5, 10]:
    print(f"x = {x} -> f(x) = {f(x)}")

watermark_material_victor_amaral_ia_2026 = True
# Out:
# x = 0 -> f(x) = 20
# x = 1 -> f(x) = 25
# x = 2 -> f(x) = 30
# x = 5 -> f(x) = 45
# x = 10 -> f(x) = 70

# %% [markdown]
# ### Exercício 1
# Complete a tabela para a função:
#
# \[
# f(x) = 5x + 20
# \]
#
# | x | f(x) |
# |---|------|
# | 0 | 20 |
# | 3 | 35 |
# | 8 | 60 |
# | 12 | 80 |
#
# > Resolva primeiro no caderno. Depois, confira com Python.

# %%
# Confira aqui o Exercício 1
def f(x):
    return 5*x + 20

for x in [0, 3, 8, 12]:
    print(f"x = {x} -> f(x) = {f(x)}")
# Out:
# x = 0 -> f(x) = 20
# x = 3 -> f(x) = 35
# x = 8 -> f(x) = 60
# x = 12 -> f(x) = 80

# %% [markdown]
# ## 4. Representação gráfica
#
# A função linear gera uma **reta** no plano cartesiano.
#
# Vamos visualizar o exemplo anterior.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 21) # 0 a 21
y = 5*x + 20

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Função linear: f(x) = 5x + 20")
plt.xlabel("GB armazenados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### O que observar no gráfico?
# 1. A reta é crescente ou decrescente?
# 2. Onde ela corta o eixo y?
# 3. O que acontece com o custo quando `x` aumenta?
#
# ### Exercício 2
# Observe o gráfico e responda:
#
# - qual é o valor de `a`?
# - qual é o valor de `b`?
# - o que cada um representa no contexto do problema?

# %% [markdown]
# ## 5. Construindo a função a partir do problema
#
# ### Exemplo 2
# Um serviço de API cobra:
#
# - taxa fixa de **R\$ 100 por mês**
# - mais **R\$ 0,50 por requisição**
#
# Se `x` representa a quantidade de requisições, então:
#
# \[
# f(x) = 0,5x + 100
# \]
#
# ### Exercício 3
# Monte a função para cada situação:
#
# 1. Uma academia cobra taxa de matrícula de R\$ 80 e mensalidade de R\$ 90.
# 2. Um streaming cobra R\$ 15 fixos e R\$ 3 por filme alugado.
# 3. Um aplicativo cobra R\$ 12 de taxa base e R$ 4 por entrega.
#
# Escreva no formato:
#
# \[
# f(x) = ax + b
# \]

# %%
#f(x) = 0,5 + 100

lista2 = [2,4,8,10]

# taxa de matrícula de R$ 80 e mensalidade de R$ 90.
def f2(x):
    return 90*x  + 80
for x in lista2:
    print(f" O valor para {x} meses de uso é R$ {f2(x)}")


# R$ 15 fixos e R$ 3 por filme alugado.
def f3(x):
    return 3*x + 15
for x in lista2:
    print(f" O valor para {x} filmes alugados é de R$ {f3(x)}")


# R$ 12 de taxa base e R$ 4 por entrega.
def f4(x):
    return 4*x + 12
for x in lista2:
    print(f" O valor para {x} entregas é de R$ {f4(x)}")
# Out:
#  O valor para 2 meses de uso é R$ 260
#  O valor para 4 meses de uso é R$ 440
#  O valor para 8 meses de uso é R$ 800
#  O valor para 10 meses de uso é R$ 980
#  O valor para 2 filmes alugados é de R$ 21
#  O valor para 4 filmes alugados é de R$ 27
#  O valor para 8 filmes alugados é de R$ 39
#  O valor para 10 filmes alugados é de R$ 45
#  O valor para 2 entregas é de R$ 20
#  O valor para 4 entregas é de R$ 28
#  O valor para 8 entregas é de R$ 44
#  O valor para 10 entregas é de R$ 52

# %%
x = np.arange(0, 11,2 ) # pula de 25 em 25
y = f2(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Matrícula")
plt.xlabel("GB armazenados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Atividade prática com Python
#
# Agora vamos criar uma função e plotar o gráfico de outro problema.

# %%
# Exemplo 2 em Python: f(x) = 0.5x + 100

def custo_api(x):
    return 0.5*x + 100

for x in [0, 50, 100, 200]:
    print(f"Requisições: {x:3d} -> Custo: R$ {custo_api(x):.2f}")
# Out:
# Requisições:   0 -> Custo: R$ 100.00
# Requisições:  50 -> Custo: R$ 125.00
# Requisições: 100 -> Custo: R$ 150.00
# Requisições: 200 -> Custo: R$ 200.00

# %%
x = np.arange(0, 301, 25)
y = 0.5*x + 100

plt.figure(figsize=(8, 5))
plt.plot(x, y, marker='o')
plt.title("Custo de uso de API")
plt.xlabel("Quantidade de requisições")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

x = np.arange(0, 21) # 0 a 21
y = 5*x + 20

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Função linear: f(x) = 5x + 20")
plt.xlabel("GB armazenados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercício 4
# Crie uma função em Python para a seguinte situação:
#
# Um plano de estudos online cobra:
# - taxa fixa de R\$ 30
# - mais R\$ 7 por curso extra contratado
#
# Tarefas:
# 1. escreva a função matemática;
# 2. crie a função em Python;
# 3. calcule os valores para `x = 0, 1, 3, 5, 10`;
# 4. plote o gráfico.

# %%
# taxa fixa de R$ 30 mais R$ 7 por curso extra contratado

def custo_plano_estudos(x):
    return 7*x + 30

for x in [0, 1, 3, 5, 10]:
    print(f" O valor para {x} cursos contradados é de R$ {custo_plano_estudos(x)}")
# Out:
#  O valor para 0 cursos contradados é de R$ 30
#  O valor para 1 cursos contradados é de R$ 37
#  O valor para 3 cursos contradados é de R$ 51
#  O valor para 5 cursos contradados é de R$ 65
#  O valor para 10 cursos contradados é de R$ 100

# %%
x = np.array([0,1,3,5,10]) # pula de 5 em 5
y = custo_plano_estudos(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Plano de Estudos")
plt.xlabel("Qtd_Cursos_Contratados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Aplicação em IA: previsão com função linear
#
# Agora vem a conexão com Inteligência Artificial.
#
# Imagine que queremos prever o preço de uma casa com base no tamanho dela.
#
# Temos os seguintes dados:
#
# | Tamanho (m²) | Preço (mil R$) |
# |-------------|----------------|
# | 50          | 100            |
# | 60          | 120            |
# | 70          | 140            |
#
# Perceba que existe um padrão:
#
# - a cada 10 m², o preço aumenta 20 mil;
# - isso equivale a 2 mil por m².
#
# Podemos escrever:
#
# \[
# preço = 2x
# \]
#
# ou, no formato geral:
#
# \[
# f(x) = 2x + 0
# \]
#
# ### O que isso tem a ver com IA?
# Nesse caso:
#
# - `x` = variável de entrada (**feature**)
# - `f(x)` = valor previsto
# - `a` = peso (**weight**)
# - `b` = viés (**bias**)
#
# > Em Machine Learning, um dos objetivos é encontrar automaticamente os melhores valores de `a` e `b`.

# %%
# Simulando uma previsão simples com função linear

def preco_casa(tamanho):
    return 2*tamanho  # em mil reais

for tamanho in [45, 55, 80, 100]:
    print(f"Tamanho: {tamanho} m² -> Preço previsto: R$ {preco_casa(tamanho)*1000:,.2f}")
# Out:
# Tamanho: 45 m² -> Preço previsto: R$ 90,000.00
# Tamanho: 55 m² -> Preço previsto: R$ 110,000.00
# Tamanho: 80 m² -> Preço previsto: R$ 160,000.00
# Tamanho: 100 m² -> Preço previsto: R$ 200,000.00

# %% [markdown]
# ## 8. Regressão linear: uma IA aprendendo a reta
#
# Agora vamos usar uma biblioteca para ajustar automaticamente uma reta aos dados.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Dados
X = np.array([50, 60, 70]).reshape(-1, 1)   # entrada
y = np.array([100, 120, 140])               # saída

# Modelo
modelo = LinearRegression() #aqui ele está vazio
modelo.fit(X, y) # recebe os valores de X e y

print("Coeficiente a:", modelo.coef_[0])
print("Interceptor b:", modelo.intercept_)

# Previsão
novo_valor = np.array([[85]])
previsao = modelo.predict(novo_valor)

print(f"Preço previsto para 85 m²: {previsao[0]:.2f} mil reais")
# Out:
# Coeficiente a: 2.0
# Interceptor b: 0.0
# Preço previsto para 85 m²: 170.00 mil reais

# %% [markdown]
# \[
# f(x) = 5x + 20
# \]
#
# | x | f(x) |
# |---|------|
# | 0 | 20 |
# | 3 | 35 |
# | 8 | 60 |
# | 12 | 80 |

# %%
# Dados
X = np.array([0, 3, 8, 12]).reshape(-1, 1)   # entrada
y = np.array([20, 35, 60, 80])               # saída

# Modelo
modelo = LinearRegression() #aqui ele está vazio
modelo.fit(X, y) # recebe os valores de X e y

print("Coeficiente a:", modelo.coef_[0])
print("Interceptor b:", modelo.intercept_)

# Previsão
novo_valor = np.array([[85]])
previsao = modelo.predict(novo_valor)

print(f"Preço previsto para 85 m²: {previsao[0]:.2f} mil reais")
# Out:
# Coeficiente a: 4.999999999999999
# Interceptor b: 20.000000000000004
# Preço previsto para 85 m²: 445.00 mil reais

# %% [markdown]
# ### Interpretação
# O modelo encontrou automaticamente uma função do tipo:
#
# \[
# f(x) = ax + b
# \]
#
# Ou seja, ele aprendeu a melhor reta para representar os dados.
#
# ### Onde vocês usarão isso no futuro?
# Ao construir IA, vocês usarão esse raciocínio em:
#
# - regressão linear;
# - classificação com soma ponderada;
# - redes neurais (camadas fazem operações lineares);
# - análise de dados e previsão;
# - ajuste de parâmetros em modelos.
#
# > Mesmo quando o modelo é mais complexo, a lógica matemática de entrada, peso e saída continua aparecendo.

# %% [markdown]
# ## 9. Exercícios práticos
#
# ### Exercício 5
# Uma plataforma de computação em nuvem cobra R\$ 50 fixos por mês e R\$ 12 por hora de uso de GPU.
#
# 1. Escreva a função.
# 2. Calcule o custo para 0, 2, 5 e 10 horas.
# 3. Diga o que representam `a` e `b`.
#
# ---
#
# ### Exercício 6
# Uma empresa vende assinaturas de um software de IA:
# - taxa inicial: R\$ 200
# - R$ 25 por usuário cadastrado
#
# 1. Escreva a função.
# 2. Faça a tabela para `x = 1, 5, 10, 20`.
# 3. Faça o gráfico.
#
# ---
#
# ### Exercício 7
# Explique com suas palavras:
#
# 1. o que é uma função linear;
# 2. o que significa o coeficiente angular `a`;
# 3. o que significa o coeficiente linear `b`;
# 4. como isso aparece em IA.

# %%
"""
Uma plataforma de computação em nuvem cobra R$ 50 fixos por mês e R$ 12 por hora de uso de GPU.

Escreva a função.
Calcule o custo para 0, 2, 5 e 10 horas.
Diga o que representam a e b.

"""


def plataforma_computação(x):
    return 12*x + 50

for x in [0, 2, 5, 10]:
    print(f" O valor para {x} horas de curso por uso de GPU é de R$ {plataforma_computação(x)}")



X = np.array([0, 2, 5, 10]).reshape(-1, 1)   # entrada
y = np.array([50,74,110,170])               # saída

# Modelo
modelo = LinearRegression() #aqui ele está vazio
modelo.fit(X, y) # recebe os valores de X e y

print("Coeficiente a:", modelo.coef_[0])
print("Interceptor b:", modelo.intercept_)

"""
# Previsão
novo_valor = np.array([[85]])
previsao = modelo.predict(novo_valor)

print(f"Preço previsto para 85 m²: {previsao[0]:.2f} mil reais")

"""
# Out:
#  O valor para 0 horas de curso por uso de GPU é de R$ 50
#  O valor para 2 horas de curso por uso de GPU é de R$ 74
#  O valor para 5 horas de curso por uso de GPU é de R$ 110
#  O valor para 10 horas de curso por uso de GPU é de R$ 170
# Coeficiente a: 12.000000000000002
# Interceptor b: 49.99999999999999
# '\n# Previsão\nnovo_valor = np.array([[85]])\nprevisao = modelo.predict(novo_valor)\n\nprint(f"Preço previsto para 85 m²: {previsao[0]:.2f} mil reais")\n\n'

# %%
"""
Uma empresa vende assinaturas de um software de IA:

taxa inicial: R$ 200
R$ 25 por usuário cadastrado
Escreva a função.
Faça a tabela para x = 1, 5, 10, 20.
Faça o gráfico.

"""

def assinatura_ia(x):
    return 25*x + 200

for x in [1,5,10,20]:
    print(f" O valor para {x} usuário(s) cadastrado(s) é de  {assinatura_ia(x)}")


x = np.array([1,5,10,20])
y = assinatura_ia(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Assinatura IA")
plt.xlabel("Qtd_Cursos_Contratados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()
# Out:
#  O valor para 1 usuário(s) cadastrado(s) é de  225
#  O valor para 5 usuário(s) cadastrado(s) é de  325
#  O valor para 10 usuário(s) cadastrado(s) é de  450
#  O valor para 20 usuário(s) cadastrado(s) é de  700

# %%
"""
Explique com suas palavras:

o que é uma função linear;
o que significa o coeficiente angular a;
o que significa o coeficiente linear b;
como isso aparece em IA.

"""

# é uma expressão matemática do primeiro grau que representa uma relação linear entre variáveis.
# define a inclinação da reta, função sobe ou desce
# intercepta, reta corta o eixo y
# Regressão Linear e Rede Neural
# Out:
# '\nExplique com suas palavras:\n\no que é uma função linear;\no que significa o coeficiente angular a;\no que significa o coeficiente linear b;\ncomo isso aparece em IA.\n\n'

# %% [markdown]
# ## 10. Exercícios de interpretação
#
# ### Exercício 8
# Dada a função:
#
# \[
# f(x) = 3x + 15
# \]
#
# Responda:
# 1. A função é crescente ou decrescente?
# 2. Qual é a taxa de variação?
# 3. Qual é o valor inicial?
# 4. Quanto vale `f(10)`?
#
# ---
#
# ### Exercício 9
# Dada a função:
#
# \[
# f(x) = -2x + 8
# \]
#
# Responda:
# 1. A função é crescente ou decrescente?
# 2. O que significa o sinal negativo do coeficiente angular?
# 3. Quanto vale `f(0)`?
# 4. Faça uma tabela com os valores para `x = 0, 1, 2, 3, 4`.
#
# ---
#
# ### Exercício 10
# Crie um problema do cotidiano que possa ser modelado por uma função linear.
# Depois:
#
# 1. escreva a função;
# 2. explique o significado de `a` e `b`;
# 3. construa uma tabela com 5 valores;
# 4. faça o gráfico.

# %%
"""
[ f(x) = 3x + 15 ]

Responda:

A função é crescente ou decrescente?
Qual é a taxa de variação?
Qual é o valor inicial?
Quanto vale f(10)?

"""
#crescente, coeficiente de x é posisitivo
# 3
# 15
def f(x):
    return 3*x + 15

print(f(10))
#45
# Out:
# 45

# %%
"""
[ f(x) = -2x + 8 ]

Responda:

A função é crescente ou decrescente?
O que significa o sinal negativo do coeficiente angular?
Quanto vale f(0)?
Faça uma tabela com os valores para x = 0, 1, 2, 3, 4.
"""
# decrescente, o coeficiente é negativo -2
# indica que a função é decrescente, que a reta se inclina para baixo da esquerda para a direita

def f(x):
    return -2*x + 8

print(f(0))


x = np.array([0, 1, 2, 3, 4])
y = f(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Assinatura IA")
plt.xlabel("Qtd_Cursos_Contratados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()
# Out:
# 8

# %%
"""
Crie um problema do cotidiano que possa ser modelado por uma função linear.
Depois:

escreva a função;
explique o significado de a e b;
construa uma tabela com 5 valores;
faça o gráfico.

"""


"""
loja distribuidora de bebidas:

taxa fixa: R$ 50
R$ 100 por garrafa de tequila
Escreva a função.
Faça a tabela para x = 1, 5, 10, 20.
Faça o gráfico.

"""

def assinatura_loja(x):
    return 100*x + 50

for x in [3,5,10,20]:
    print(f" O valor para {x} garrafas de tequila por usuário cadastrado é de R$ {assinatura_loja(x)}")


x = np.array([3,5,10,20])
y = assinatura_loja(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Assinatura IA")
plt.xlabel("Qtd_Garrafas")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

X = np.array([3,5,10,20]).reshape(-1, 1)   # entrada
y = np.array([350,550,1050,2050])               # saída

# Modelo
modelo = LinearRegression() #aqui ele está vazio
modelo.fit(X, y) # recebe os valores de X e y

print("Coeficiente a:", modelo.coef_[0])
print("Interceptor b:", modelo.intercept_)
# Out:
#  O valor para 3 garrafas de tequila por usuário cadastrado é de R$ 350
#  O valor para 5 garrafas de tequila por usuário cadastrado é de R$ 550
#  O valor para 10 garrafas de tequila por usuário cadastrado é de R$ 1050
#  O valor para 20 garrafas de tequila por usuário cadastrado é de R$ 2050
# Coeficiente a: 100.00000000000001
# Interceptor b: 49.999999999999886

# %% [markdown]
# # 11. Desafios opcionais — nível avançado
#
# Os exercícios abaixo são **opcionais** e destinados aos alunos que quiserem ir além.
#
# ---
#
# ## Desafio 1 — Comparando dois planos
#
# Uma empresa oferece dois planos para uso de processamento em nuvem:
#
# - **Plano A:** R\$ 40 fixos + R\$ 8 por hora de uso
# - **Plano B:** R\$ 100 fixos + R\$ 5 por hora de uso
#
# Tarefas:
# 1. escreva as duas funções;
# 2. calcule os custos para 0, 5, 10, 20 horas;
# 3. faça os dois gráficos no mesmo plano cartesiano;
# 4. descubra a partir de quantas horas o Plano B passa a ser mais vantajoso;
# 5. interprete o resultado.
#
# ---
#
# ## Desafio 2 — Encontrando a função a partir da tabela
#
# Determine a função linear correspondente à tabela:
#
# | x | y |
# |---|---|
# | 1 | 7 |
# | 2 | 11 |
# | 3 | 15 |
# | 4 | 19 |
#
# Tarefas:
# 1. descubra o valor de `a`;
# 2. descubra o valor de `b`;
# 3. escreva a função;
# 4. faça o gráfico;
# 5. explique como identificou a taxa de variação.
#
# ---
#
# ## Desafio 3 — Pequeno projeto de IA
#
# Considere os dados:
#
# | Horas de estudo | Nota |
# |-----------------|------|
# | 1               | 4    |
# | 2               | 5    |
# | 3               | 6    |
# | 4               | 7    |
# | 5               | 8    |
#
# Tarefas:
# 1. construa um modelo linear para esses dados;
# 2. use Python para ajustar uma regressão linear;
# 3. preveja a nota para 6 e 8 horas de estudo;
# 4. compare a fórmula criada manualmente com a fórmula aprendida pelo modelo.
#
# ---
#
# ## Desafio 4 — Análise crítica
#
# Pesquise ou reflita:
#
# - toda relação em IA pode ser modelada por uma reta?
# - quais limitações um modelo linear possui?
# - em quais situações seria necessário usar modelos mais complexos?
#
# Escreva uma resposta curta de 8 a 12 linhas.

# %%
"""
Uma empresa oferece dois planos para uso de processamento em nuvem:

Plano A: R$ 40 fixos + R$ 8 por hora de uso
Plano B: R$ 100 fixos + R$ 5 por hora de uso
Tarefas:

escreva as duas funções;
calcule os custos para 0, 5, 10, 20 horas;
faça os dois gráficos no mesmo plano cartesiano;
descubra a partir de quantas horas o Plano B passa a ser mais vantajoso;
interprete o resultado.

"""

import numpy as np
import matplotlib.pyplot as plt

"""
def plano_a(x):
    return 8*x + 40
for x in [0, 5, 10, 20]:
    print(f"Para {x} horas de uso do Plano A é de R$ {plano_a(x)}")


def plano_b(x):
    return 5*x + 100
for x in [0, 5, 10, 20]:
    print(f"Para {x} horas de uso do Plano B é de R$ {plano_b(x)}")

"""
def plano_a(x):
    return 8*x + 40

def plano_b(x):
    return 5*x + 100

horas_uso = [0, 5, 10, 20]

print(f'Para o Plano A:')
for x in horas_uso:
    print(f"Para {x}h de uso do Plano A é de R$ {plano_a(x)}")


print(f'Para o Plano B:')
for x in horas_uso:
    print(f"Para {x}h de uso do Plano B é de R$ {plano_b(x)}")

x = np.array(horas_uso)
y_plano_a = plano_a(x)
y_plano_b = plano_b(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y_plano_a, marker='o', label ='Plano A') # tipo de gráfico
plt.plot(x, y_plano_b, marker='s', label ='Plano B')
plt.title("Planos")
plt.xlabel("Qtd_Horas")
plt.ylabel("Custo total (R$)")
plt.legend()
plt.grid(True)
plt.show()




"""
x = np.array([3,5,10,20])
y = assinatura_loja(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Assinatura IA")
plt.xlabel("Qtd_Cursos_Contratados")
plt.ylabel("Custo total (R$)")
plt.grid(True)
plt.show()

X = np.array([3,5,10,20]).reshape(-1, 1)   # entrada
y = np.array([350,550,1050,2050])               # saída

# Modelo
modelo = LinearRegression() #aqui ele está vazio
modelo.fit(X, y) # recebe os valores de X e y

print("Coeficiente a:", modelo.coef_[0])
print("Interceptor b:", modelo.intercept_)
"""
# Out:
# Para o Plano A:
# Para 0h de uso do Plano A é de R$ 40
# Para 5h de uso do Plano A é de R$ 80
# Para 10h de uso do Plano A é de R$ 120
# Para 20h de uso do Plano A é de R$ 200
# Para o Plano B:
# Para 0h de uso do Plano B é de R$ 100
# Para 5h de uso do Plano B é de R$ 125
# Para 10h de uso do Plano B é de R$ 150
# Para 20h de uso do Plano B é de R$ 200
# '\nx = np.array([3,5,10,20])\ny = assinatura_loja(x)\n\nplt.figure(figsize=(8, 5)) # configurar a área da figura\nplt.plot(x, y, marker=\'o\') # tipo de gráfico\nplt.title("Assinatura IA")\nplt.xlabel("Qtd_Cursos_Contratados")\nplt.ylabel("Custo total (R$)")\nplt.grid(True)\nplt.show()\n\nX = np.array([3,5,10,20]).reshape(-1, 1)   # entrada\ny = np.array([350,550,1050,2050])               # saída\n\n# Modelo\nmodelo = LinearRegression() #aqui ele está vazio\nmodelo.fit(X, y) # recebe os valores de X e y\n\nprint("Coeficiente a:", modelo.coef_[0])\nprint("Interceptor b:", modelo.intercept_)\n'

# %%
"""
Determine a função linear correspondente à tabela:

| x | y |
|---|---|
| 1 | 7 |
| 2 | 11 |
| 3 | 15 |
| 4 | 19 |
Tarefas:

descubra o valor de a;
descubra o valor de b;
escreva a função;
faça o gráfico;
explique como identificou a taxa de variação.

"""


"""
y/x  y2 - y1 / x2 - x1
     11 - 7 /  2 - 1
        4/1
         a = 4

x=1
y=7
        ou f(x)
        y = ax + b
        7 = 4*1 + b   7 = 4 + b   b = 7 - 4
                    b = 3
                f(x) = 4x + 3

"""
def func(x):
    return 4*x + 3


x = np.array([1,2,3,4])
y = func(x)

plt.figure(figsize=(8, 5)) # configurar a área da figura
plt.plot(x, y, marker='o') # tipo de gráfico
plt.title("Função : f(x) = 4x + 3")
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_531/1382421464.py:48: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
"""
Considere os dados:

| Horas de estudo | Nota |
|-----------------|------|
| 1               | 4    |
| 2               | 5    |
| 3               | 6    |
| 4               | 7    |
| 5               | 8    |

Tarefas:

construa um modelo linear para esses dados;
use Python para ajustar uma regressão linear;
preveja a nota para 6 e 8 horas de estudo;
compare a fórmula criada manualmente com a fórmula aprendida pelo modelo.

"""

x = np.array([1,2,3,4,5]).reshape(-1, 1)  # entrada
y = np.array([4,5,6,7,8])  # saída


# Modelo
modelo = LinearRegression() #aqui ele está vazio
modelo.fit(x, y) # recebe os valores de X e y

print("6 horas:", modelo.predict([[6]]))
print("8 horas:", modelo.predict([[8]]))
# Out:
# 6 horas: [9.]
# 8 horas: [11.]

# %%
"""
Pesquise ou reflita:

toda relação em IA pode ser modelada por uma reta?
quais limitações um modelo linear possui?
em quais situações seria necessário usar modelos mais complexos?
Escreva uma resposta curta de 8 a 12 linhas.

"""

# %%
#não, apenas quando a relação entre as variáveis é proporcional e o comportamento é simples e previsível, mas dados são não lineares eles possuem curvas, picos, quedas
#
#

# %% [markdown]
# # 12. Fechamento da aula
#
# ## Ideias principais
# - Função linear tem a forma `f(x) = ax + b`.
# - `a` representa a taxa de crescimento ou decrescimento.
# - `b` representa o valor inicial.
# - Funções lineares ajudam a modelar situações do cotidiano.
# - Em IA, elas aparecem como base de modelos preditivos simples.
# - Regressão linear é uma aplicação direta desse conteúdo.
#
# ## Perguntas finais para reflexão
# 1. Onde você enxerga função linear no seu dia a dia?
# 2. Qual a relação entre função linear e regressão linear?
# 3. Por que esse conteúdo é importante para quem vai estudar IA?
